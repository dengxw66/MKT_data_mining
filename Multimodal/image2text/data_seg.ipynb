# %%
import cv2
import os

def extract_frames(video_path, output_folder, interval=3):
    # 确保输出文件夹存在
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # 打开视频文件
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"无法打开视频文件: {video_path}")
        return

    # 获取视频的帧率
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_interval = int(fps * interval)  # 每隔interval秒提取一帧

    frame_count = 0
    saved_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        if frame_count % frame_interval == 0:
            frame_name = os.path.join(output_folder, f"frame_{saved_count:04d}.jpg")
            cv2.imwrite(frame_name, frame)
            print(f"保存图片: {frame_name}")
            saved_count += 1

        frame_count += 1

    cap.release()
    print("完成所有帧的提取")

# 使用示例
video_path = 'D:/Python/SCGC/tiktok/data/input/0595ca4d8a26132a0d33cddecfd7d0e1.mp4'
output_folder = 'D:/Python/SCGC/tiktok/data/output'
extract_frames(video_path, output_folder)

# %%
import os
from PIL import Image

def process_images(input_folder, output_folder):
    # 确保输出文件夹存在
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    # 初始化文件计数器
    file_counter = 0
    
    # 获取并排序输入文件夹中的所有文件
    file_list = sorted([f for f in os.listdir(input_folder) if f.endswith(".jpg") or f.endswith(".png") or f.endswith(".jpeg")])

    # 遍历排序后的文件列表
    for filename in file_list:
        if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
            # 构建输入文件路径
            input_path = os.path.join(input_folder, filename)
            # 打开图像
            img = Image.open(input_path)
            width, height = img.size
            
            # 计算新图像的区域
            left = width * 7 / 8
            top = height / 2
            right = width
            bottom = height
            
            # 裁剪图像
            cropped_img = img.crop((left, top, right, bottom))
            
            # 构建输出文件路径，使用序号保存文件
            output_path = os.path.join(output_folder, f"{file_counter}.png")
            # 保存裁剪后的图像
            cropped_img.save(output_path)
            print(f"保存裁剪后的图片: {output_path}")
            
            # 更新文件计数器
            file_counter += 1

# 使用示例
input_folder = '/data1/dxw_data/llm/tiktok/data/output'
output_folder = '/data1/dxw_data/llm/tiktok/data/output_likes'
process_images(input_folder, output_folder)
# Out:
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/0.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/1.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/2.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/3.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/4.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/5.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/6.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/7.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/8.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/9.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/10.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/11.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/12.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/13.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/14.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/15.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/16.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/17.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/18.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/19.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/20.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/21.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/22.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/23.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/24.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/25.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/26.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/27.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/28.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/29.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/30.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/31.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/32.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/33.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/34.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/35.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/36.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/37.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/38.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/39.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/40.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/41.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/42.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/43.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/44.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/45.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/46.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/47.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/48.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/49.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/50.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/51.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/52.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/53.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/54.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_likes/55.png

# %%
import os
from PIL import Image


def process_images(input_folder, output_folder):
    # 确保输出文件夹存在
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    # 初始化文件计数器
    file_counter = 0
    
    # 获取并排序输入文件夹中的所有文件
    file_list = sorted([f for f in os.listdir(input_folder) if f.endswith(".jpg") or f.endswith(".png") or f.endswith(".jpeg")])

    # 遍历排序后的文件列表
    for filename in file_list:
        if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
            # 构建输入文件路径
            input_path = os.path.join(input_folder, filename)
            # 打开图像
            img = Image.open(input_path)
            width, height = img.size
            
            # 计算新图像的区域
            left = 0
            top = height * 7 / 10
            right = width
            bottom = height * 9 / 10
            
            # 裁剪图像
            cropped_img = img.crop((left, top, right, bottom))
            
            # 构建输出文件路径，使用序号保存文件
            output_path = os.path.join(output_folder, f"{file_counter}.png")
            # 保存裁剪后的图像
            cropped_img.save(output_path)
            print(f"保存裁剪后的图片: {output_path}")
            
            # 更新文件计数器
            file_counter += 1

# 使用示例
input_folder = '/data1/dxw_data/llm/tiktok/data/output'
output_folder = '/data1/dxw_data/llm/tiktok/data/output_title'
process_images(input_folder, output_folder)
# Out:
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/0.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/1.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/2.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/3.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/4.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/5.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/6.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/7.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/8.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/9.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/10.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/11.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/12.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/13.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/14.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/15.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/16.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/17.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/18.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/19.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/20.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/21.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/22.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/23.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/24.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/25.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/26.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/27.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/28.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/29.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/30.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/31.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/32.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/33.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/34.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/35.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/36.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/37.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/38.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/39.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/40.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/41.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/42.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/43.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/44.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/45.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/46.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/47.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/48.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/49.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/50.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/51.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/52.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/53.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/54.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_title/55.png

# %%
import os
from PIL import Image

def process_images(input_folder, output_folder):
    # 确保输出文件夹存在
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    # 初始化文件计数器
    file_counter = 0
    
    # 获取并排序输入文件夹中的所有文件
    file_list = sorted([f for f in os.listdir(input_folder) if f.endswith(".jpg") or f.endswith(".png") or f.endswith(".jpeg")])

    # 遍历排序后的文件列表
    for filename in file_list:
        if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
            # 构建输入文件路径
            input_path = os.path.join(input_folder, filename)
            # 打开图像
            img = Image.open(input_path)
            width, height = img.size
            
            # 计算新图像的区域
            left = 0
            top = height * 3 / 9
            right = width
            bottom = height * 8 / 9
            
            # 裁剪图像
            cropped_img = img.crop((left, top, right, bottom))
            
            # 构建输出文件路径，使用序号保存文件
            output_path = os.path.join(output_folder, f"{file_counter}.png")
            # 保存裁剪后的图像
            cropped_img.save(output_path)
            print(f"保存裁剪后的图片: {output_path}")
            
            # 更新文件计数器
            file_counter += 1

# 使用示例
input_folder = '/data1/dxw_data/llm/tiktok/data/output'
output_folder = '/data1/dxw_data/llm/tiktok/data/output_comments'
process_images(input_folder, output_folder)
# Out:
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/0.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/1.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/2.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/3.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/4.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/5.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/6.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/7.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/8.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/9.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/10.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/11.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/12.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/13.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/14.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/15.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/16.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/17.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/18.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/19.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/20.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/21.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/22.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/23.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/24.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/25.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/26.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/27.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/28.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/29.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/30.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/31.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/32.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/33.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/34.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/35.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/36.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/37.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/38.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/39.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/40.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/41.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/42.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/43.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/44.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/45.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/46.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/47.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/48.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/49.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/50.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/51.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/52.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/53.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/54.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_comments/55.png

# %%
import os
from PIL import Image

def process_images(input_folder, output_folder):
    # 确保输出文件夹存在
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
    # 初始化文件计数器
    file_counter = 0
    
    # 获取并排序输入文件夹中的所有文件
    file_list = sorted([f for f in os.listdir(input_folder) if f.endswith(".jpg") or f.endswith(".png") or f.endswith(".jpeg")])

    # 遍历排序后的文件列表
    for filename in file_list:
        if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
            # 构建输入文件路径
            input_path = os.path.join(input_folder, filename)
            # 打开图像
            img = Image.open(input_path)
            width, height = img.size
            
            # 计算新图像的区域
            left = 0
            top = height * 3 / 9
            right = width
            bottom = height * 8 / 9
            
            # 裁剪图像
            cropped_img = img.crop((left, top, right, bottom))
            
            # 构建输出文件路径，使用序号保存文件
            output_path = os.path.join(output_folder, f"{file_counter}.png")
            # 保存裁剪后的图像
            cropped_img.save(output_path)
            print(f"保存裁剪后的图片: {output_path}")
            
            # 更新文件计数器
            file_counter += 1

# 使用示例
input_folder = '/data1/dxw_data/llm/tiktok/data/output'
output_folder = '/data1/dxw_data/llm/tiktok/data/output_caption'
process_images(input_folder, output_folder)
# Out:
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/0.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/1.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/2.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/3.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/4.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/5.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/6.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/7.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/8.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/9.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/10.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/11.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/12.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/13.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/14.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/15.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/16.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/17.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/18.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/19.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/20.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/21.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/22.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/23.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/24.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/25.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/26.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/27.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/28.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/29.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/30.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/31.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/32.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/33.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/34.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/35.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/36.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/37.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/38.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/39.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/40.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/41.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/42.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/43.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/44.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/45.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/46.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/47.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/48.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/49.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/50.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/51.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/52.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/53.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/54.png
# 保存裁剪后的图片: /data1/dxw_data/llm/tiktok/data/output_caption/55.png
